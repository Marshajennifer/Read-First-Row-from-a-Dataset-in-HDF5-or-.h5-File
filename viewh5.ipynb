# %%
import h5py

# Open an existing HDF5 file
file = h5py.File('train.h5', 'r')  # 'r' is for read-only mode

# List all groups
print("Keys: %s" % file.keys())
a_group_key = list(file.keys())[0]

# Get the data from the first group
data = list(file[a_group_key])

# Print the data
print(data)

# Always remember to close the file when you're done
file.close()
# Out:
# Keys: <KeysViewHDF5 ['center', 'imgname', 'index', 'name', 'name_', 'normalize', 'part', 'person', 'scale', 'torsoangle', 'visible']>
# ...

# %%
first_row = dataset[0]  # Indexing starts at 0, so 0 refers to the first row

# Print the first row
print(first_row)

# Always remember to close the file when you're done to ensure resources are freed
file.close()

# %%
import h5py

# Open the HDF5 file
file = h5py.File('train.h5', 'r')

# Print all keys (datasets available in this file)
print("Keys: %s" % file.keys())

# Choose a dataset to inspect, for example 'part'
dataset_name = 'part'

# Check if the dataset name exists in the file
if dataset_name in file:
    # Access the dataset
    dataset = file[dataset_name]
    
    # Access and print the first row of the dataset
    first_row = dataset[0]  # Get the first row
    print('First row of dataset "%s":' % dataset_name, first_row)
else:
    print('Dataset named "%s" not found in file.' % dataset_name)

# Close the file
file.close()
# Out:
# Keys: <KeysViewHDF5 ['center', 'imgname', 'index', 'name', 'name_', 'normalize', 'part', 'person', 'scale', 'torsoangle', 'visible']>
# First row of dataset "part": [[620. 394.]
#  [616. 269.]
#  [573. 185.]
#  [647. 188.]
#  [661. 221.]
#  [656. 231.]
#  [610. 187.]
#  [647. 176.]
#  [637. 189.]
#  [695. 108.]
#  [606. 217.]
#  [553. 161.]
#  [601. 167.]
#  [692. 185.]
#  [693. 240.]
#  [688. 313.]]

# %%
import h5py

# Open the HDF5 file
file = h5py.File('train.h5', 'r')

# Print all keys (datasets available in this file)
print("Keys: %s" % file.keys())

# Choose a dataset to inspect, for example 'part'
dataset_name = 'imgname'

# Check if the dataset name exists in the file
if dataset_name in file:
    # Access the dataset
    dataset = file[dataset_name]
    
    # Access and print the first row of the dataset
    first_row = dataset[0]  # Get the first row
    print('First row of dataset "%s":' % dataset_name, first_row)
else:
    print('Dataset named "%s" not found in file.' % dataset_name)

# Close the file
file.close()
# Out:
# Keys: <KeysViewHDF5 ['center', 'imgname', 'index', 'name', 'name_', 'normalize', 'part', 'person', 'scale', 'torsoangle', 'visible']>
# First row of dataset "imgname": b'015601864.jpg'

# %%
import h5py

# Open the HDF5 file
file = h5py.File('train.h5', 'r')

# Print all keys (datasets available in this file)
print("Keys: %s" % file.keys())

# Choose a dataset to inspect, for example 'part'
dataset_name = 'person'

# Check if the dataset name exists in the file
if dataset_name in file:
    # Access the dataset
    dataset = file[dataset_name]
    
    # Access and print the first row of the dataset
    first_row = dataset[0]  # Get the first row
    print('First row of dataset "%s":' % dataset_name, first_row)
else:
    print('Dataset named "%s" not found in file.' % dataset_name)

# Close the file
file.close()
# Out:
# Keys: <KeysViewHDF5 ['center', 'imgname', 'index', 'name', 'name_', 'normalize', 'part', 'person', 'scale', 'torsoangle', 'visible']>
# First row of dataset "person": 0
